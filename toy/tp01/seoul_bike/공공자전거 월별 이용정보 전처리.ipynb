# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# 한글
import matplotlib

matplotlib.rcParams['font.family'] ='Malgun Gothic'

matplotlib.rcParams['axes.unicode_minus'] =False

# %%
# 엑셀파일 전처리 csv로 (1807~1812)

# %%
# 2018 엑셀파일 전처리 (1807~1812)
forders = os.listdir('공공자전거_월별_이용정보/')
xl_all = pd.DataFrame()
cnt = 7
for i in range(0,len(forders)):
    if forders[i].split('.')[2] == 'xlsx':
        file = '공공자전거_월별_이용정보/'+forders[i]
        xl= pd.read_excel(file)
        xl.iloc[:,0] = f"2018-{cnt}"
        xl_all = pd.concat([xl_all, xl])
        cnt = cnt+1
xl_all.to_csv("서울특별시 공공자전거 이용정보(월별)_18.0712.csv", index=False, encoding='utf-8-sig')
# Out:
# C:\Users\comss\AppData\Local\Temp\ipykernel_16456\3870893823.py:9: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   xl.iloc[:,0] = f"2018-{cnt}"
# C:\Users\comss\AppData\Local\Temp\ipykernel_16456\3870893823.py:9: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   xl.iloc[:,0] = f"2018-{cnt}"
# ...

# %%
# 2019 엑셀파일 전처리 (1901~1911)
forders = os.listdir('공공자전거_월별_이용정보/')
xl_all = pd.DataFrame()
cnt = 1
for i in range(0,len(forders)):
    if forders[i].split('.')[2] == 'xlsx':
        file = '공공자전거_월별_이용정보/'+forders[i]
        xl= pd.read_excel(file)
        xl.iloc[:,0] = f"2019-{cnt}"
        xl_all = pd.concat([xl_all, xl])
        cnt = cnt+1
# Out:
# C:\Users\h\AppData\Local\Temp\ipykernel_17232\1925975158.py:8: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   xl.iloc[:,0] = f"2019-{cnt}"
# C:\Users\h\AppData\Local\Temp\ipykernel_17232\1925975158.py:8: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   xl.iloc[:,0] = f"2019-{cnt}"
# ...

# %%
xl_all.to_csv("공공자전거_월별_이용정보/서울특별시 공공자전거 이용정보(월별)_19.0111csv", index=False, encoding='utf-8-sig')

# %%
## 년도별 이용정보 합치기

# 17년
forders = os.listdir('공공자전거_월별_이용정보/')
df_all = pd.DataFrame()
for i in range(0,len(forders)):
    if forders[i].split('.')[0][-2:] == '17':
        file = "공공자전거_월별_이용정보/"+forders[i]
        df= pd.read_csv(file, encoding='utf-8')
        df.columns = ['대여일자', '대여소번호', '대여소명', '대여구분코드', '성별', '연령대코드', '이용건수', '운동량', '탄소량', '이동거리(M)', '이용시간(분)']
        for j in range(0,6):
            df.iloc[:,j] = (df.iloc[:,j]).str.replace("'", "")
        df_all = pd.concat([df_all, df])
        
df_all.to_csv("공공자전거_월별_이용정보/서울특별시 공공자전거 이용정보(월별)_17.csv", index=False, encoding='utf-8-sig')

# %%
check = pd.read_csv("연도별/서울특별시 공공자전거 이용정보(월별)_17.csv")

# %%
check
# Out:
#            대여일자 대여소번호                      대여소명 대여구분코드 성별 연령대코드  이용건수     운동량  \
# 0       2017-01   503               더샵스타시티 C동 앞     정기  F  ~10대     7  389.44
# 1       2017-01   509               이마트 버스정류소 옆     정기  F  ~10대     2  239.50
# 2       2017-01   300                     정동사거리     정기  F  ~10대     2  370.93
# 3       2017-01   301               경복궁역 7번출구 앞     정기  F  ~10대     3  140.03
# 4       2017-01   304               광화문역 2번출구 앞     정기  F  ~10대     1   28.10
# ...         ...   ...                       ...    ... ..   ...   ...     ...
# 217455  2017-12  2002                  노들역 1번출구     단체  M   50대     1  190.99
# 217456  2017-12  2003                    사육신공원앞     단체  M   50대     1  181.21
# 217457  2017-12  1303                   돈암초교 입구     단체  M   50대     2  239.78
# 217458  2017-12  2219   고속터미널역 8-1번, 8-2번 출구 사이     단체  M   60대     3  615.66
# 217459  2017-12   576                광나루역 3번 출구     단체  M  70대~     4  494.98
#
#          탄소량  이동거리(M)  이용시간(분)
# ...

# %%
# 18년 상반기
forders = os.listdir('공공자전거_월별_이용정보/')
df_all = pd.DataFrame()
for i in range(0,len(forders)):
    if forders[i].split('.')[0][21:24] == '18':
        file = "공공자전거_월별_이용정보/"+forders[i]
        df= pd.read_csv(file, encoding='utf-8')
        df.columns = ['대여일자', '대여소번호', '대여소명', '대여구분코드', '성별', '연령대코드', '이용건수', '운동량', '탄소량', '이동거리(M)', '이용시간(분)']
        for j in range(0,6):
            df.iloc[:,j] = (df.iloc[:,j]).str.replace("'", "")
        df_all = pd.concat([df_all, df])
        
df_all.to_csv("서울특별시 공공자전거 이용정보(월별)_18.0106.csv", index=False, encoding='utf-8-sig')

# %%
# 18년 상반기 + 하반기
forders = os.listdir('공공자전거_월별_이용정보/')
df_all = pd.DataFrame()
for i in range(0,len(forders)):
    if forders[i].split('.')[0][21:24] == '18':
        file = "공공자전거_월별_이용정보/"+forders[i]
        df= pd.read_csv(file, encoding='utf-8')
        df.columns = ['대여일자', '대여소번호', '대여소명', '대여구분코드', '성별', '연령대코드', '이용건수', '운동량', '탄소량', '이동거리(M)', '이용시간(분)']
        df_all = pd.concat([df_all, df])

# %%
# 7, 8, 9 월 데이터 오류 수정
df_all.iloc[:,0] = df_all.iloc[:,0].str.replace("2018-7","2018-07")
df_all.iloc[:,0] = df_all.iloc[:,0].str.replace("2018-8","2018-08")
df_all.iloc[:,0] = df_all.iloc[:,0].str.replace("2018-9","2018-09")

df_all.to_csv("서울특별시 공공자전거 이용정보(월별)_2018.csv", index=False, encoding='utf-8-sig')

# %%
# 19년
forders = os.listdir('공공자전거_월별_이용정보/')
df19 = pd.DataFrame()
a = pd.read_csv("공공자전거_월별_이용정보/서울특별시 공공자전거 이용정보(월별)_19.0111.csv", encoding='utf-8')
a.columns = ['대여일자', '대여소번호', '대여소명', '대여구분코드', '성별', '연령대코드', '이용건수', '운동량', '탄소량', '이동거리(M)', '이용시간(분)']

# 이때부터 인코딩방식 바꿈
b = pd.read_csv("공공자전거_월별_이용정보/서울특별시 공공자전거 이용정보(월별)_19.12.csv", encoding='CP949')
b.columns = ['대여일자', '대여소번호', '대여소명', '대여구분코드', '성별', '연령대코드', '이용건수', '운동량', '탄소량', '이동거리(M)', '이용시간(분)']

df19 = pd.concat([a,b])

# 19년도 1~9월 데이터 오류
df19.iloc[:,0] = df19.iloc[:,0].str.replace("2019-1","2019-01")
df19.iloc[:,0] = df19.iloc[:,0].str.replace("2019-2","2019-02")
df19.iloc[:,0] = df19.iloc[:,0].str.replace("2019-3","2019-03")
df19.iloc[:,0] = df19.iloc[:,0].str.replace("2019-4","2019-04")
df19.iloc[:,0] = df19.iloc[:,0].str.replace("2019-5","2019-05")
df19.iloc[:,0] = df19.iloc[:,0].str.replace("2019-6","2019-06")
df19.iloc[:,0] = df19.iloc[:,0].str.replace("2019-7","2019-07")
df19.iloc[:,0] = df19.iloc[:,0].str.replace("2019-8","2019-08")
df19.iloc[:,0] = df19.iloc[:,0].str.replace("2019-9","2019-09")


df19.to_csv("연도별/서울특별시 공공자전거 이용정보(월별)_19.csv", index=False, encoding='utf-8-sig')

# %%
check = pd.read_csv("연도별/서울특별시 공공자전거 이용정보(월별)_19.csv")

# %%
check
# Out:
#            대여일자  대여소번호            대여소명  대여구분코드  성별    연령대코드  이용건수      운동량  \
# 0        2019-1      3            중랑센터  일일(회원)   M  AGE_003    12   288.87
# 1        2019-1      3            중랑센터  일일(회원)   M  AGE_004     8   424.63
# 2        2019-1      3            중랑센터  일일(회원)   M  AGE_005    27  4579.48
# 3        2019-1      3            중랑센터      정기   M  AGE_003    17   3438.8
# 4        2019-1      5        상암센터 정비실  일일(회원)   M  AGE_004     1    78.31
# ...         ...    ...             ...     ...  ..      ...   ...      ...
# 675204  2019-12   9999          시스템관리팀  일일(회원)  \N  AGE_002     1       \N
# 675205  2019-12  99998   99998. 상암단말정비      정기  \N  AGE_005     3     5.11
# 675206  2019-12  99999  99999. 영남단말기정비      정기  \N  AGE_002     1        0
# 675207  2019-12  99999  99999. 영남단말기정비      정기  \N  AGE_004     2    44.78
# 675208  2019-12  99999  99999. 영남단말기정비      정기   M  AGE_004    19  9186.81
#
#           탄소량  이동거리(M)  이용시간(분)
# 0        2.25     9690      117
# ...

# %%
# 20년 - 5월까지 utf
forders = os.listdir('공공자전거_월별_이용정보/')
df_all = pd.DataFrame()
for i in range(0,len(forders)):   
    if forders[i].split('.')[1] == '06':
        break
    
    elif forders[i].split('.')[0][-2:] == '20':
        file = "공공자전거_월별_이용정보/"+forders[i]
        df= pd.read_csv(file, encoding='utf-8')
        df.columns = ['대여일자', '대여소번호', '대여소명', '대여구분코드', '성별', '연령대코드', '이용건수', '운동량', '탄소량', '이동거리(M)', '이용시간(분)']
        df_all = pd.concat([df_all, df])

df_all.to_csv("공공자전거_월별_이용정보/서울특별시 공공자전거 이용정보(월별)_20.0105.csv", index=False, encoding='utf-8-sig')

# %%
# 20년 - 6,7월은 CP949
forders = os.listdir('공공자전거_월별_이용정보/')
df_all = pd.DataFrame()
for i in range(0,len(forders)):   
    if forders[i].split('.')[1] == '08':
        break
    
    elif forders[i].split('.')[0][-2:] == '20':
        file = "공공자전거_월별_이용정보/"+forders[i]
        df= pd.read_csv(file, encoding='CP949')
        df.columns = ['대여일자', '대여소번호', '대여소명', '대여구분코드', '성별', '연령대코드', '이용건수', '운동량', '탄소량', '이동거리(M)', '이용시간(분)']
        df_all = pd.concat([df_all, df])

df_all.to_csv("공공자전거_월별_이용정보/서울특별시 공공자전거 이용정보(월별)_20.0607.csv", index=False, encoding='utf-8-sig')

# %%
# 20년 - 8월부터 utf
forders = os.listdir('공공자전거_월별_이용정보/')
df_all = pd.DataFrame()
for i in range(0,len(forders)):
    if forders[i].split('.')[0][21:24] == '20':
        print(forders[i])
        file = "공공자전거_월별_이용정보/"+forders[i]
        df= pd.read_csv(file, encoding='utf-8')
        df.columns = ['대여일자', '대여소번호', '대여소명', '대여구분코드', '성별', '연령대코드', '이용건수', '운동량', '탄소량', '이동거리(M)', '이용시간(분)']
        df_all = pd.concat([df_all, df])
        
df_all.to_csv("연도별/서울특별시 공공자전거 이용정보(월별)_20.0812.csv", index=False, encoding='utf-8-sig')
# Out:
# 서울특별시 공공자전거 이용정보(월별)_20.08.csv
# 서울특별시 공공자전거 이용정보(월별)_20.09.csv
# 서울특별시 공공자전거 이용정보(월별)_20.10.csv
# 서울특별시 공공자전거 이용정보(월별)_20.11.csv
# 서울특별시 공공자전거 이용정보(월별)_20.12.csv

# %%
# 20년 - 8월부터 utf
forders = os.listdir('공공자전거_월별_이용정보/')
df_all = pd.DataFrame()
for i in range(0,len(forders)):
    if forders[i].split('.')[0][21:24] == '20':
        print(forders[i])
        file = "공공자전거_월별_이용정보/"+forders[i]
        df= pd.read_csv(file, encoding='utf-8')
        df.columns = ['대여일자', '대여소번호', '대여소명', '대여구분코드', '성별', '연령대코드', '이용건수', '운동량', '탄소량', '이동거리(M)', '이용시간(분)']
        df_all = pd.concat([df_all, df])
        
df_all.to_csv("연도별/서울특별시 공공자전거 이용정보(월별)_20.csv", index=False, encoding='utf-8-sig')
# Out:
# 서울특별시 공공자전거 이용정보(월별)_20.0105.csv
# 서울특별시 공공자전거 이용정보(월별)_20.0607.csv
# 서울특별시 공공자전거 이용정보(월별)_20.0812.csv

# %%
check = pd.read_csv("연도별/서울특별시 공공자전거 이용정보(월별)_20.csv")

# %%
check
# Out:
#            대여일자  대여소번호            대여소명  대여구분코드  성별    연령대코드  이용건수      운동량  \
# 0       2020-01      3            중랑센터  일일(회원)   M  AGE_003     3    61.82
# 1       2020-01      3            중랑센터  일일(회원)   M  AGE_004     1    39.62
# 2       2020-01      3            중랑센터      정기   M  AGE_005     3   430.85
# 3       2020-01      5        상암센터 정비실  일일(회원)  \N  AGE_005     2     1.79
# 4       2020-01      5        상암센터 정비실      정기   F  AGE_003     1  4501.96
# ...         ...    ...             ...     ...  ..      ...   ...      ...
# 948882  2020-12   9999          시스템관리팀      정기   F  AGE_006     1       \N
# 948883  2020-12   9999          시스템관리팀      정기   M  AGE_003     2     0.00
# 948884  2020-12   9999          시스템관리팀      정기   M  AGE_004     1       \N
# 948885  2020-12  99999  99999. 영남단말기정비      정기  \N  AGE_008     7     0.00
# 948886  2020-12  99999  99999. 영남단말기정비      정기   M  AGE_004     3     0.00
#
#           탄소량   이동거리(M)  이용시간(분)
# 0        0.52    2230.0       75
# ...

# %%
# 21년
forders = os.listdir('공공자전거_월별_이용정보/')
df_all = pd.DataFrame()
for i in range(0,len(forders)):
    if forders[i].split('.')[0][21:24] == '21':
        print(forders[i])
        file = "공공자전거_월별_이용정보/"+forders[i]
        df= pd.read_csv(file, encoding='CP949')
        df.columns = ['대여일자', '대여소번호', '대여소명', '대여구분코드', '성별', '연령대코드', '이용건수', '운동량', '탄소량', '이동거리(M)', '이용시간(분)']
        df_all = pd.concat([df_all, df])
        
df_all.to_csv("연도별/서울특별시 공공자전거 이용정보(월별)_21.csv", index=False, encoding='utf-8-sig')
# Out:
# 서울특별시 공공자전거 이용정보(월별)_21.01.csv
# 서울특별시 공공자전거 이용정보(월별)_21.02.csv
# 서울특별시 공공자전거 이용정보(월별)_21.03.csv
# 서울특별시 공공자전거 이용정보(월별)_21.04.csv
# 서울특별시 공공자전거 이용정보(월별)_21.05.csv
# 서울특별시 공공자전거 이용정보(월별)_21.06.csv
# 서울특별시 공공자전거 이용정보(월별)_21.07.csv
# 서울특별시 공공자전거 이용정보(월별)_21.08.csv
# 서울특별시 공공자전거 이용정보(월별)_21.09.csv
# 서울특별시 공공자전거 이용정보(월별)_21.10.csv
# 서울특별시 공공자전거 이용정보(월별)_21.11.csv
# 서울특별시 공공자전거 이용정보(월별)_21.12.csv

# %%
# 22년
forders = os.listdir('공공자전거_월별_이용정보/')
df_all = pd.DataFrame()
for i in range(0,len(forders)):
    if forders[i].split('.')[0][21:24] == '22':
        print(forders[i])
        file = "공공자전거_월별_이용정보/"+forders[i]
        df= pd.read_csv(file, encoding='CP949')
        df.columns = ['대여일자', '대여소번호', '대여소명', '대여구분코드', '성별', '연령대코드', '이용건수', '운동량', '탄소량', '이동거리(M)', '이용시간(분)']
        df_all = pd.concat([df_all, df])
        
df_all.to_csv("연도별/서울특별시 공공자전거 이용정보(월별)_22.csv", index=False, encoding='utf-8-sig')
# Out:
# 서울특별시 공공자전거 이용정보(월별)_22.01.csv
# 서울특별시 공공자전거 이용정보(월별)_22.02.csv
# 서울특별시 공공자전거 이용정보(월별)_22.03.csv
# 서울특별시 공공자전거 이용정보(월별)_22.04.csv
# 서울특별시 공공자전거 이용정보(월별)_22.05.csv
# 서울특별시 공공자전거 이용정보(월별)_22.06.csv

# %%
# 데이터 취합하기
forders = os.listdir('연도별/')
df_all = pd.DataFrame()
for i in range(0,len(forders)):
    if forders[i].split('.')[1] == 'csv':
        print(forders[i])
        file = "연도별/"+forders[i]
        df= pd.read_csv(file, encoding='utf-8')
        df_all = pd.concat([df_all, df])
# Out:
# 서울특별시 공공자전거 이용정보(월별)_17.csv
# 서울특별시 공공자전거 이용정보(월별)_18.csv
# C:\Users\comss\AppData\Local\Temp\ipykernel_16456\3959340210.py:8: DtypeWarning: Columns (1,7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df= pd.read_csv(file, encoding='utf-8')
# 서울특별시 공공자전거 이용정보(월별)_19.csv
# 서울특별시 공공자전거 이용정보(월별)_20.csv
# 서울특별시 공공자전거 이용정보(월별)_21.csv
# 서울특별시 공공자전거 이용정보(월별)_22.csv

# %%
df_all
# Out:
#            대여일자  대여소번호            대여소명 대여구분코드  성별 연령대코드  이용건수     운동량   탄소량  \
# 0       2017-01    503     더샵스타시티 C동 앞     정기   F  ~10대     7  389.44  3.51
# 1       2017-01    509     이마트 버스정류소 옆     정기   F  ~10대     2   239.5  2.33
# 2       2017-01    300           정동사거리     정기   F  ~10대     2  370.93  2.68
# 3       2017-01    301     경복궁역 7번출구 앞     정기   F  ~10대     3  140.03  1.26
# 4       2017-01    304     광화문역 2번출구 앞     정기   F  ~10대     1    28.1   0.3
# ...         ...    ...             ...    ...  ..   ...   ...     ...   ...
# 715502  2022-06   9999            상담센터     정기   M    기타     4  525.03  3.84
# 715503  2022-06  88888      88888.영남배송     정기   M   60대     7  831.71  7.62
# 715504  2022-06  99998   99998. 상암단말정비     정기  \N   20대     1   20.85  0.26
# 715505  2022-06  99999  99999. 영남단말기정비     정기  \N    기타    15    0.00  0.00
# 715506  2022-06  99999  99999. 영남단말기정비     정기   M   30대     1   14.71  0.11
#
#          이동거리(M)  이용시간(분)
# 0       15130.00      105
# ...

# %%
SeoulBike = pd.DataFrame(df_all.groupby('대여일자')['운동량'].count()).reset_index()

# %%
SeoulBike.columns = ['이용일','이용자']

# %%
SeoulBike
# Out:
#         이용일     이용자
# 0   2017-01    7292
# 1   2017-02    8158
# 2   2017-03   12773
# 3   2017-04   15223
# 4   2017-05   22037
# ..      ...     ...
# 60  2022-02   98177
# 61  2022-03  116725
# 62  2022-04  132952
# 63  2022-05  137729
# 64  2022-06  133101
#
# [65 rows x 2 columns]

# %%
fig = plt.figure(figsize=(20, 10), facecolor='white')
plt.xlabel('연-월', fontsize=20)
plt.ylabel('총 이용자', fontsize=20)
plt.xticks(fontsize = 14, rotation = 70)
plt.yticks(fontsize = 14)
plt.title('월별 따릉이 이용자 수', fontsize=20)
plt.plot(SeoulBike['이용일'], SeoulBike['이용자'], color='green', linewidth=3)
plt.show()
